# %%
print(560)
# Out:
# 560

# %% [markdown]
# # Python第一堂課
# ## 輸出內容

# %%
print("你好!") #函式
# Out:
# 你好!

# %%
"""
作者:Howard
日期:2023/07/06
xxxxxx
"""

a = 1.34
print(a)
#print(b)
你好 = "Hi!!"
print(你好)
var1 = 25
print(var1)#這是輸出25
# Out:
# 1.34
# Hi!!
# 25

# %%
var1 = 100
print(var1)
var1 = "Hello"
print(var1)
var1 = 100,"Ken"
print(var1)

print(var1.__class__)
a = 100
b = a * 10
print(b)
a = 12.3
b = a * 10
print(b)
a = "Hello"
b = a * 10
print(b)
# Out:
# 100
# Hello
# (100, 'Ken')
# <class 'tuple'>
# 1000
# 123.0
# HelloHelloHelloHelloHelloHelloHelloHelloHelloHello

# %%
a = 10
b = 3.14
c = 'test'
print(a,b,c)
#a = 50,b=3.14,c="Vivin" #這樣會錯
a,b,c = 50,3.16,"Vivin"
print(a,b,c)
# Out:
# 10 3.14 test
# 50 3.16 Vivin

# %%
a ,b =50,76
print(a,b)
c = a
a = b
b = c
print(a,b)
# Out:
# 50 76
# 76 50

# %%
a,b = 50,76
print(a,b)
a,b = b,a
print(a,b)
# Out:
# 50 76
# 76 50

# %%
# 互斥 XOR
a ,b =50,76
print(a,b)
a = a ^ b
b = a ^ b
a = a ^ b
print(a,b)
# Out:
# 50 76
# 76 50

# %% [markdown]
# ## 可利用str()轉字串

# %%
yaer = 28
st1 = '你的'
st2 = '年齡是'
print(st1,st2,yaer)
print(st1+st2,yaer)
# print(st1+st2+yaer)
print(st1+st2+str(yaer))
# Out:
# 你的 年齡是 28
# 你的年齡是 28
# 你的年齡是28

# %%
x,y,z = 3,6,9
print(x,y,z)
x=y=z=30
print(x,y,z)
# Out:
# 3 6 9
# 30 30 30

# %%
a,b,c= 4,5,6
print(a,b,c)
del c
#print(a,b,c)#NameError: name 'c' is not defined
print(a,b)
# Out:
# 4 5 6
# 4 5

# %%
a,b = 10,3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)

a,b = 10,5
c = a/b
print(a/b)
print(a//b)
print(int(c))
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 2.0
# 2
# 2

# %%
a,b = 10,3.14
print("整數資料為:",a)
print("整數資料為:"+str(a))
print("浮點數資料:",b)
print("浮點數資料:"+str(b))
# Out:
# 整數資料為: 10
# 整數資料為:10
# 浮點數資料: 3.14
# 浮點數資料:3.14

# %% [markdown]
# ## 輸入資料
# ### input("可放提示詞")
#
# 輸入的資料一律都是字串類型

# %%
a = input("請輸入一個數字")
print(type(a))
b = a * 2
print(b)
c = int(a)
ans = c * 2
print(ans)
# Out:
# 請輸入一個數字25
# <class 'str'>
# 2525
# 50

# %% [markdown]
# ## 測試計算

# %%
a,b,c = 4,2,5
d,f = 3.25,5.5
print(a*b)
print(a**b)
print(a%3)
print(d + f)
print(c //b)
print(c /b)
print(a / b)
print(a // b)
# Out:
# 8
# 16
# 1
# 8.75
# 2
# 2.5
# 2.0
# 2

# %%
ch = 2
ans = ch + 10 * 5
print(ans)
ans = (ch + 10) * 5
print(ans)
# Out:
# 52
# 60

# %%
ch = 4
ans = (ch+2) * (ch-3)/10
print(ans)
# Out:
# 0.6

# %%
ch = 4
ans = ch + 2 * ch - 3
print(ans)
# Out:
# 9

# %%
coin = 0
coin +=  1
print(coin)
#coin = coin + 2
coin += 2
print(coin)
# Out:
# 1
# 3

# %% [markdown]
# ![image.png](attachment:image.png)
